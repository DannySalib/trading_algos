# %%
import pandas as pd
from system import Config, State

cfg = Config(
    strategy='Global Equity Momentum'
)
state = State()

# %%
from system.visualize import plot_portfolio_equity
fig = plot_portfolio_equity(cfg, state)
# Out:
# 100%|██████████| 525/525 [00:00<00:00, 6480.22it/s]

# %%
from system.visualize import export_report_pdf

export_report_pdf(cfg, state, path='./reports/simple_global_equity_momentum_report.pdf')
# Out:
# Report saved to: ./reports/simple_global_equity_momentum_report.pdf
