# %%
# For Alpaca (the trading platform),
# historical close prices for stocks
# are determined by the primary exchange's
# closing auction or last trade at 4:00 PM ET
# during regular market hours

# TODO assert that all signals uses a skip day and a look back such that no future bias is created...
