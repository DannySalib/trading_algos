# %% [markdown]
# # Learning Backtrader
# ### [How To](https://algotrading101.com/learn/backtrader-for-backtesting/#:~:text=covers%20adding%20data.-,How%20to%20configure%20the%20basic%20Backtrader%20setup,-There%20are%20two)

# %%
# !pip install backtrader
