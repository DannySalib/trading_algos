# %% [markdown]
# # Better Dashboards and More complex Strategies / Analysis
# - [quantstats library](https://pypi.org/project/quantstats/)
# - [how to load historial ticker data](https://pypi.org/project/quantstats/)

# %%
# TODO
# - explore monte carlo simulations for backtesting
# - explore quantstats library
# - understand a walk forward analysis
# Project IDEA : a trading strategy management API
# it's probably best to memorize basic quant formulas before just using libraries

# %% [markdown]
# ##### Backtesting The Donchain Breakout Strategy
# - [youtube link](https://www.youtube.com/watch?v=NLBXgSmRBgU&t=327s)
# - [github link](https://github.com/neurotrader888/mcpt)

# %%
# TODO:
# debug `mcpt-main\mcpt-main\donchian.py`
# debug `mcpt-main\mcpt-main\bar_permute.py`
# debug `mcpt-main\mcpt-main\insample_donchian_mcpt.py`

# %%
# TODO
# back test
